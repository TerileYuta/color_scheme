# %%
#インポート

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import csv

# %%
#データの読み込み
data = []

filename = '/content/drive/MyDrive/アルバイト/PreApp/Asset/ColorList(1).csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)
    for row in csvreader:
        data.append(row)

# %%
#データ整形

data.pop(0)
data = [*map(lambda row: list(map(lambda x: int(x), row)), data)]

data_x = np.array([*map(lambda x: np.array(x[3:6])/ 255, data)])
data_y = np.array([*map(lambda x: np.array(x[:3]) / 255, data)])

# %%
#Discriminatorクラス

class discriminator(nn.Module):
    def __init__(self):
        super(discriminator, self).__init__()

        self.fc1 = nn.Linear(3, 512)
        self.fc2 = nn.Linear(512, 1)
        self.activation = nn.LeakyReLU(0.1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)

        return nn.Sigmoid()(x)

# %%
#Generatorクラス

class generator(nn.Module):
    def __init__(self):
        super(generator, self).__init__()

        self.fc1 = nn.Linear(3, 1024)
        self.fc2 = nn.Linear(1024, 2048)
        self.fc3 = nn.Linear(2048, 3)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.fc3(x)

        return nn.Tanh()(x)

# %%
#ハイパーパラメータの設定

# GPU利用可否確認
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

epochs = 30
lr = 2e-4
batch_size = 64
bce_loss = nn.BCEWithLogitsLoss()
mae_loss = nn.L1Loss()

G = generator().to(device)
D = discriminator().to(device)

G_optimizer = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
D_optimizer = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
#学習

for epoch in range(epochs):
    for idx, x in enumerate(data_x):
        idx += 1

        #True Color
        real_y = data_y[idx-1]

        input_x = torch.tensor(x, dtype=torch.float32).to(device)
        real_y = torch.tensor(real_y, dtype=torch.float32).to(device)

        fake_color = G(input_x)
        fake_color_tensor = fake_color.detach()
        fake_output = D(fake_color)

        #lossを計算するためのラベル
        real_label = torch.ones(1, requires_grad=True).to(device)
        fake_label = torch.zeros(1, requires_grad=True).to(device)

        #Generateの訓練
        loss_G_bce = bce_loss(fake_output, real_label)
        loss_G_mae = mae_loss(fake_color, real_y)
        loss_G_sum = loss_G_bce + loss_G_mae

        #重みの更新
        G_optimizer.zero_grad()
        D_optimizer.zero_grad()
        loss_G_sum.backward()
        G_optimizer.step()

        #Discriminatorの訓練
        real_output = D(real_y)
        fake_output = D(fake_color_tensor)

        #損失関数の計算
        loss_D_real = bce_loss(real_output, real_label)
        loss_D_fake = bce_loss(fake_output, fake_label)
        loss_D_sum = loss_D_real + loss_D_fake

        #重みの更新
        G_optimizer.zero_grad()
        D_optimizer.zero_grad()
        loss_D_sum.backward()
        D_optimizer.step()

        if idx % 100 == 0 or idx == len(data_x):
            print('Epoch {} Iteration {}: discriminator_loss {:.3f} generator_loss {:.3f}'.format(epoch, idx, loss_D_sum.item(), loss_G_sum_tmp.item()))

    if (epoch+1) % 100 == 0:
        torch.save(G, 'Generator_epoch_{}.pth'.format(epoch))
        print('Model saved.')
# Out:
# Epoch 0 Iteration 100: discriminator_loss 1.397 generator_loss 0.638
# Epoch 0 Iteration 200: discriminator_loss 1.399 generator_loss 0.684
# Epoch 0 Iteration 300: discriminator_loss 1.394 generator_loss 0.822
# Epoch 0 Iteration 400: discriminator_loss 1.393 generator_loss 0.679
# Epoch 0 Iteration 500: discriminator_loss 1.393 generator_loss 0.725
# Epoch 0 Iteration 588: discriminator_loss 1.400 generator_loss 0.702
# Epoch 1 Iteration 100: discriminator_loss 1.410 generator_loss 0.743
# Epoch 1 Iteration 200: discriminator_loss 1.386 generator_loss 0.675
# Epoch 1 Iteration 300: discriminator_loss 1.393 generator_loss 0.891
# Epoch 1 Iteration 400: discriminator_loss 1.388 generator_loss 0.698
# Epoch 1 Iteration 500: discriminator_loss 1.408 generator_loss 0.828
# Epoch 1 Iteration 588: discriminator_loss 1.433 generator_loss 0.717
# Epoch 2 Iteration 100: discriminator_loss 1.403 generator_loss 0.773
# Epoch 2 Iteration 200: discriminator_loss 1.388 generator_loss 0.703
# Epoch 2 Iteration 300: discriminator_loss 1.391 generator_loss 0.904
# Epoch 2 Iteration 400: discriminator_loss 1.388 generator_loss 0.685
# Epoch 2 Iteration 500: discriminator_loss 1.387 generator_loss 0.931
# Epoch 2 Iteration 588: discriminator_loss 1.406 generator_loss 0.703
# Epoch 3 Iteration 100: discriminator_loss 1.409 generator_loss 0.711
# Epoch 3 Iteration 200: discriminator_loss 1.387 generator_loss 0.671
# Epoch 3 Iteration 300: discriminator_loss 1.389 generator_loss 0.906
# Epoch 3 Iteration 400: discriminator_loss 1.389 generator_loss 0.692
# Epoch 3 Iteration 500: discriminator_loss 1.407 generator_loss 0.775
# Epoch 3 Iteration 588: discriminator_loss 1.432 generator_loss 0.607
# Epoch 4 Iteration 100: discriminator_loss 1.393 generator_loss 0.711
# Epoch 4 Iteration 200: discriminator_loss 1.385 generator_loss 0.690
# Epoch 4 Iteration 300: discriminator_loss 1.389 generator_loss 0.898
# Epoch 4 Iteration 400: discriminator_loss 1.387 generator_loss 0.688
# Epoch 4 Iteration 500: discriminator_loss 1.406 generator_loss 0.812
# Epoch 4 Iteration 588: discriminator_loss 1.434 generator_loss 0.741
# Epoch 5 Iteration 100: discriminator_loss 1.410 generator_loss 0.704
# Epoch 5 Iteration 200: discriminator_loss 1.386 generator_loss 0.670
# Epoch 5 Iteration 300: discriminator_loss 1.390 generator_loss 0.926
# Epoch 5 Iteration 400: discriminator_loss 1.388 generator_loss 0.712
# Epoch 5 Iteration 500: discriminator_loss 1.383 generator_loss 0.918
# Epoch 5 Iteration 588: discriminator_loss 1.408 generator_loss 0.695
# Epoch 6 Iteration 100: discriminator_loss 1.413 generator_loss 0.710
# Epoch 6 Iteration 200: discriminator_loss 1.386 generator_loss 0.684
# Epoch 6 Iteration 300: discriminator_loss 1.393 generator_loss 0.919
# Epoch 6 Iteration 400: discriminator_loss 1.387 generator_loss 0.694
# Epoch 6 Iteration 500: discriminator_loss 1.395 generator_loss 0.764
# Epoch 6 Iteration 588: discriminator_loss 1.396 generator_loss 0.650
# Epoch 7 Iteration 100: discriminator_loss 1.390 generator_loss 0.675
# Epoch 7 Iteration 200: discriminator_loss 1.390 generator_loss 0.671
# Epoch 7 Iteration 300: discriminator_loss 1.391 generator_loss 0.910
# Epoch 7 Iteration 400: discriminator_loss 1.394 generator_loss 0.713
# Epoch 7 Iteration 500: discriminator_loss 1.387 generator_loss 0.810
# Epoch 7 Iteration 588: discriminator_loss 1.432 generator_loss 0.668
# Epoch 8 Iteration 100: discriminator_loss 1.421 generator_loss 0.756
# Epoch 8 Iteration 200: discriminator_loss 1.384 generator_loss 0.683
# Epoch 8 Iteration 300: discriminator_loss 1.391 generator_loss 0.872
# Epoch 8 Iteration 400: discriminator_loss 1.389 generator_loss 0.693
# Epoch 8 Iteration 500: discriminator_loss 1.389 generator_loss 0.788
# Epoch 8 Iteration 588: discriminator_loss 1.394 generator_loss 0.679
# Epoch 9 Iteration 100: discriminator_loss 1.395 generator_loss 0.683
# Epoch 9 Iteration 200: discriminator_loss 1.387 generator_loss 0.684
# Epoch 9 Iteration 300: discriminator_loss 1.392 generator_loss 0.928
# Epoch 9 Iteration 400: discriminator_loss 1.390 generator_loss 0.724
# Epoch 9 Iteration 500: discriminator_loss 1.379 generator_loss 0.872
# Epoch 9 Iteration 588: discriminator_loss 1.399 generator_loss 0.680
# Epoch 10 Iteration 100: discriminator_loss 1.402 generator_loss 0.699
# Epoch 10 Iteration 200: discriminator_loss 1.385 generator_loss 0.674
# Epoch 10 Iteration 300: discriminator_loss 1.391 generator_loss 0.862
# Epoch 10 Iteration 400: discriminator_loss 1.384 generator_loss 0.719
# Epoch 10 Iteration 500: discriminator_loss 1.406 generator_loss 0.717
# Epoch 10 Iteration 588: discriminator_loss 1.403 generator_loss 0.694
# Epoch 11 Iteration 100: discriminator_loss 1.389 generator_loss 0.758
# Epoch 11 Iteration 200: discriminator_loss 1.389 generator_loss 0.693
# Epoch 11 Iteration 300: discriminator_loss 1.393 generator_loss 0.906
# Epoch 11 Iteration 400: discriminator_loss 1.386 generator_loss 0.716
# Epoch 11 Iteration 500: discriminator_loss 1.378 generator_loss 0.859
# Epoch 11 Iteration 588: discriminator_loss 1.392 generator_loss 0.633
# Epoch 12 Iteration 100: discriminator_loss 1.398 generator_loss 0.693
# Epoch 12 Iteration 200: discriminator_loss 1.394 generator_loss 0.673
# Epoch 12 Iteration 300: discriminator_loss 1.395 generator_loss 0.903
# Epoch 12 Iteration 400: discriminator_loss 1.382 generator_loss 0.750
# Epoch 12 Iteration 500: discriminator_loss 1.410 generator_loss 0.728
# Epoch 12 Iteration 588: discriminator_loss 1.383 generator_loss 0.662
# Epoch 13 Iteration 100: discriminator_loss 1.413 generator_loss 0.766
# Epoch 13 Iteration 200: discriminator_loss 1.398 generator_loss 0.670
# Epoch 13 Iteration 300: discriminator_loss 1.400 generator_loss 0.955
# Epoch 13 Iteration 400: discriminator_loss 1.388 generator_loss 0.700
# Epoch 13 Iteration 500: discriminator_loss 1.384 generator_loss 0.842
# Epoch 13 Iteration 588: discriminator_loss 1.408 generator_loss 0.663
# Epoch 14 Iteration 100: discriminator_loss 1.390 generator_loss 0.774
# Epoch 14 Iteration 200: discriminator_loss 1.383 generator_loss 0.678
# Epoch 14 Iteration 300: discriminator_loss 1.398 generator_loss 0.952
# Epoch 14 Iteration 400: discriminator_loss 1.387 generator_loss 0.700
# Epoch 14 Iteration 500: discriminator_loss 1.387 generator_loss 0.807
# Epoch 14 Iteration 588: discriminator_loss 1.395 generator_loss 0.657
# Epoch 15 Iteration 100: discriminator_loss 1.393 generator_loss 0.709
# Epoch 15 Iteration 200: discriminator_loss 1.381 generator_loss 0.704
# Epoch 15 Iteration 300: discriminator_loss 1.394 generator_loss 0.911
# Epoch 15 Iteration 400: discriminator_loss 1.386 generator_loss 0.707
# Epoch 15 Iteration 500: discriminator_loss 1.406 generator_loss 0.754
# Epoch 15 Iteration 588: discriminator_loss 1.383 generator_loss 0.647
# Epoch 16 Iteration 100: discriminator_loss 1.389 generator_loss 0.675
# Epoch 16 Iteration 200: discriminator_loss 1.391 generator_loss 0.642
# Epoch 16 Iteration 300: discriminator_loss 1.395 generator_loss 0.913
# Epoch 16 Iteration 400: discriminator_loss 1.382 generator_loss 0.742
# Epoch 16 Iteration 500: discriminator_loss 1.378 generator_loss 0.886
# Epoch 16 Iteration 588: discriminator_loss 1.394 generator_loss 0.644
# Epoch 17 Iteration 100: discriminator_loss 1.392 generator_loss 0.750
# Epoch 17 Iteration 200: discriminator_loss 1.399 generator_loss 0.665
# Epoch 17 Iteration 300: discriminator_loss 1.393 generator_loss 0.891
# Epoch 17 Iteration 400: discriminator_loss 1.389 generator_loss 0.705
# Epoch 17 Iteration 500: discriminator_loss 1.384 generator_loss 0.840
# Epoch 17 Iteration 588: discriminator_loss 1.399 generator_loss 0.644
# Epoch 18 Iteration 100: discriminator_loss 1.385 generator_loss 0.763
# Epoch 18 Iteration 200: discriminator_loss 1.394 generator_loss 0.705
# Epoch 18 Iteration 300: discriminator_loss 1.393 generator_loss 0.905
# Epoch 18 Iteration 400: discriminator_loss 1.386 generator_loss 0.682
# Epoch 18 Iteration 500: discriminator_loss 1.387 generator_loss 0.744
# Epoch 18 Iteration 588: discriminator_loss 1.395 generator_loss 0.627
# Epoch 19 Iteration 100: discriminator_loss 1.389 generator_loss 0.677
# Epoch 19 Iteration 200: discriminator_loss 1.395 generator_loss 0.688
# Epoch 19 Iteration 300: discriminator_loss 1.392 generator_loss 0.896
# Epoch 19 Iteration 400: discriminator_loss 1.393 generator_loss 0.644
# Epoch 19 Iteration 500: discriminator_loss 1.380 generator_loss 0.888
# Epoch 19 Iteration 588: discriminator_loss 1.382 generator_loss 0.665
# Epoch 20 Iteration 100: discriminator_loss 1.384 generator_loss 0.712
# Epoch 20 Iteration 200: discriminator_loss 1.381 generator_loss 0.722
# Epoch 20 Iteration 300: discriminator_loss 1.394 generator_loss 0.903
# Epoch 20 Iteration 400: discriminator_loss 1.386 generator_loss 0.662
# Epoch 20 Iteration 500: discriminator_loss 1.381 generator_loss 0.868
# Epoch 20 Iteration 588: discriminator_loss 1.383 generator_loss 0.679
# Epoch 21 Iteration 100: discriminator_loss 1.379 generator_loss 0.718
# Epoch 21 Iteration 200: discriminator_loss 1.394 generator_loss 0.682
# Epoch 21 Iteration 300: discriminator_loss 1.394 generator_loss 0.957
# Epoch 21 Iteration 400: discriminator_loss 1.395 generator_loss 0.633
# Epoch 21 Iteration 500: discriminator_loss 1.379 generator_loss 0.902
# Epoch 21 Iteration 588: discriminator_loss 1.390 generator_loss 0.650
# Epoch 22 Iteration 100: discriminator_loss 1.381 generator_loss 0.739
# Epoch 22 Iteration 200: discriminator_loss 1.400 generator_loss 0.654
# Epoch 22 Iteration 300: discriminator_loss 1.395 generator_loss 0.918
# Epoch 22 Iteration 400: discriminator_loss 1.372 generator_loss 0.683
# Epoch 22 Iteration 500: discriminator_loss 1.383 generator_loss 0.868
# Epoch 22 Iteration 588: discriminator_loss 1.390 generator_loss 0.643
# Epoch 23 Iteration 100: discriminator_loss 1.384 generator_loss 0.707
# Epoch 23 Iteration 200: discriminator_loss 1.413 generator_loss 0.638
# Epoch 23 Iteration 300: discriminator_loss 1.402 generator_loss 0.962
# Epoch 23 Iteration 400: discriminator_loss 1.392 generator_loss 0.637
# Epoch 23 Iteration 500: discriminator_loss 1.383 generator_loss 0.935
# Epoch 23 Iteration 588: discriminator_loss 1.386 generator_loss 0.648
# Epoch 24 Iteration 100: discriminator_loss 1.387 generator_loss 0.701
# Epoch 24 Iteration 200: discriminator_loss 1.389 generator_loss 0.697
# Epoch 24 Iteration 300: discriminator_loss 1.398 generator_loss 0.952
# Epoch 24 Iteration 400: discriminator_loss 1.391 generator_loss 0.629
# Epoch 24 Iteration 500: discriminator_loss 1.383 generator_loss 0.933
# Epoch 24 Iteration 588: discriminator_loss 1.385 generator_loss 0.680
# Epoch 25 Iteration 100: discriminator_loss 1.386 generator_loss 0.733
# Epoch 25 Iteration 200: discriminator_loss 1.441 generator_loss 0.653
# Epoch 25 Iteration 300: discriminator_loss 1.393 generator_loss 0.964
# Epoch 25 Iteration 400: discriminator_loss 1.398 generator_loss 0.614
# Epoch 25 Iteration 500: discriminator_loss 1.385 generator_loss 0.926
# Epoch 25 Iteration 588: discriminator_loss 1.387 generator_loss 0.651
# Epoch 26 Iteration 100: discriminator_loss 1.392 generator_loss 0.758
# Epoch 26 Iteration 200: discriminator_loss 1.416 generator_loss 0.649
# Epoch 26 Iteration 300: discriminator_loss 1.395 generator_loss 0.947
# Epoch 26 Iteration 400: discriminator_loss 1.372 generator_loss 0.643
# Epoch 26 Iteration 500: discriminator_loss 1.390 generator_loss 0.987
# Epoch 26 Iteration 588: discriminator_loss 1.389 generator_loss 0.647
# Epoch 27 Iteration 100: discriminator_loss 1.381 generator_loss 0.749
# Epoch 27 Iteration 200: discriminator_loss 1.365 generator_loss 0.684
# Epoch 27 Iteration 300: discriminator_loss 1.400 generator_loss 0.965
# Epoch 27 Iteration 400: discriminator_loss 1.399 generator_loss 0.609
# Epoch 27 Iteration 500: discriminator_loss 1.394 generator_loss 1.039
# Epoch 27 Iteration 588: discriminator_loss 1.379 generator_loss 0.708
# Epoch 28 Iteration 100: discriminator_loss 1.380 generator_loss 0.737
# Epoch 28 Iteration 200: discriminator_loss 1.404 generator_loss 0.654
# Epoch 28 Iteration 300: discriminator_loss 1.401 generator_loss 0.968
# Epoch 28 Iteration 400: discriminator_loss 1.321 generator_loss 0.727
# Epoch 28 Iteration 500: discriminator_loss 1.384 generator_loss 0.976
# Epoch 28 Iteration 588: discriminator_loss 1.377 generator_loss 0.725
# Epoch 29 Iteration 100: discriminator_loss 1.384 generator_loss 0.745
# Epoch 29 Iteration 200: discriminator_loss 1.350 generator_loss 0.767
# Epoch 29 Iteration 300: discriminator_loss 1.399 generator_loss 0.981
# Epoch 29 Iteration 400: discriminator_loss 1.403 generator_loss 0.585
# Epoch 29 Iteration 500: discriminator_loss 1.387 generator_loss 1.017
# Epoch 29 Iteration 588: discriminator_loss 1.378 generator_loss 0.708

# %%
#モデルの保存

torch.save(G.state_dict(), 'generator_model.pth')
